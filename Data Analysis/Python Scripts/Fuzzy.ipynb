# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("Participation_Bank_Results (1).xlsx")
data.head()
# Out:
#    Id  Equity_Ratio  Trust_Score  Job  Housing  Saving_Accounts  \
# 0   0      0.773844           15    2       10             2000
# 1   1      0.668486           15    2       10             2000
# 2   2      0.656168           10    1       10             2000
# 3   6      0.948299           15    2       10            50000
# 4   8      0.970883           10    1       10           100000
#
#    Checking_Account  Credit_Amount  Duration  Project_Viability  Total_Assets  \
# 0              2000           1169         6                  3          4000
# 1             10000           5951        48                  3         12000
# 2              2000           2096        12                  8          4000
# 3              2000           2835        24                  5         52000
# 4              2000           3059        12                  3        102000
#
#    Partnership_Score
# 0          51.403181
# 1          51.403181
# 2          84.704918
# ...

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    Id  Equity_Ratio  Trust_Score  Job  Housing  Saving_Accounts  \
# 0   0      0.773844           15    2       10             2000
# 1   1      0.668486           15    2       10             2000
# 2   2      0.656168           10    1       10             2000
# 3   6      0.948299           15    2       10            50000
# 4   8      0.970883           10    1       10           100000
#
#    Checking_Account  Credit_Amount  Duration  Project_Viability  Total_Assets  \
# 0              2000           1169         6                  3          4000
# 1             10000           5951        48                  3         12000
# 2              2000           2096        12                  8          4000
# 3              2000           2835        24                  5         52000
# 4              2000           3059        12                  3        102000
#
#    Partnership_Score
# 0          51.403181
# 1          51.403181
# 2          84.704918
# ...

# %%
df["Trust_Score"].unique()
# Out:
# array([15, 10, 20,  5])

# %%
X = df.drop(["Partnership_Score"],axis=1)
y = df["Partnership_Score"]

# %%
corr = df.drop("Housing",axis=1).corr()
new_data = df.drop(["Housing","Id","Job","Saving_Accounts","Credit_Amount","Duration","Total_Assets"],axis=1).corr()
import seaborn as sns

# %%
new_data = new_data.drop("Checking_Account")

# %%
new_data
# Out:
#                    Equity_Ratio  Trust_Score  Project_Viability  \
# Equity_Ratio           1.000000    -0.205161          -0.028840
# Trust_Score           -0.205161     1.000000           0.009240
# Project_Viability     -0.028840     0.009240           1.000000
# Partnership_Score      0.166497     0.264640           0.798238
#
#                    Partnership_Score
# Equity_Ratio                0.166497
# Trust_Score                 0.264640
# Project_Viability           0.798238
# Partnership_Score           1.000000

# %%
plt.figure(figsize=(10,8), dpi =500)
sns.heatmap(new_data,annot=True,fmt=".2f", linewidth=.5)
plt.show()

# %%
df["Trust_Score"].unique()
# Out:
# array([15, 10, 20,  5])

# %%
filtered_values_0 = np.where(df['Trust_Score']==5)
filtered_values_1 = np.where(df['Trust_Score']==10)
filtered_values_2 = np.where(df['Trust_Score']==15)
filtered_values_3 = np.where(df['Trust_Score']==20)


sum_1 = 0
sum_2 = 0
sum_3 = 0
sum_4 = 0
for i in filtered_values_1[0]:
  sum_1+=y[i]
for i in filtered_values_2[0]:
  sum_2+=y[i]
for i in filtered_values_3[0]:
  sum_3+=y[i]
for i in filtered_values_0[0]:
  sum_4+=y[i]
sum_1 = sum_1/len(filtered_values_1[0])
sum_2 = sum_2/len(filtered_values_2[0])
sum_3 = sum_3/len(filtered_values_3[0])
sum_4 = sum_4/len(filtered_values_0[0])
new_list = [sum_4,sum_1,sum_2,sum_3]
print(sum_1,sum_2,sum_3,sum_4)
# Out:
# 58.69084308835382 59.78021518591442 71.52319593851665 47.953293367197645

# %%
bar_colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:orange']

fig, ax = plt.subplots()
ax.bar([f"5 [{len(filtered_values_0[0])} person]",f"10 [{len(filtered_values_1[0])} person]",f"15 [{len(filtered_values_2[0])} person]",f"20 [{len(filtered_values_3[0])} person]"],new_list,color = bar_colors)
ax.set_ylabel("Partnership Score")
ax.set_xlabel("Trust Score")
ax.set_title("Mean Partnership Score by Trust Score")
plt.show()

# %%
bar_colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:orange']

fig, ax = plt.subplots()
ax.plot([f"0 [{len(filtered_values_0[0])} person]",f"1 [{len(filtered_values_1[0])} person]",f"2 [{len(filtered_values_2[0])} person]",f"3 [{len(filtered_values_3[0])} person]"],new_list)
ax.set_ylabel("Partnership Score")
ax.set_xlabel("Job")
ax.set_title("Mean Partnership Score by Job")
plt.show()

# %%
yeni=[len(filtered_values_0[0]),len(filtered_values_1[0]),len(filtered_values_2[0]),len(filtered_values_3[0])]
plt.bar(new_list,yeni)
# Out:
# <BarContainer object of 4 artists>
